# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 4200)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
LABEL_FILE = './labels.txt'

# %%
with open(LABEL_FILE, 'r') as f:
    lines = f.readlines()

# %%
all_labels = []
for line in lines:
    row = line.strip().split(',')
    filename = row[0]
    labels = row[1:]
    
    all_labels.extend(labels)
#     for label in labels:
#         if label not in all_labels:            
#             all_labels.append(label)

# %%
label_counts = pd.value_counts(all_labels)
n_labels = len(label_counts)
# label_counts = np.array(label_counts)

# %%
label_counts.keys()
# Out:
# Index(['portrait', 'landscape', 'genre painting', 'realism',
#        'female portraits', 'male portraits', 'impressionism',
#        'religious painting', 'christianity', 'france',
#        ...
#        'maria teresa de vallabriga', 'andrea palladio', 'allegheny city',
#        'shmelevka', 'sudislavl', 'december 12', 'the medici cycle',
#        'old windsor', 'delphic sibyl', 'gabriel alonso de herrera'],
#       dtype='object', length=4195)

# %%
size = 50
bar_width = 0.8
x_labels = np.array(label_counts.keys())[:size][::-1]
x_array = np.arange(n_labels)[:size]
y_array = label_counts.values[:size][::-1]

norm_y_array = (y_array / y_array.max()).round(2)
colors = np.vstack((norm_y_array, norm_y_array, norm_y_array)).T
colors[:, 1] = colors[:, 1] * 0.90
colors[:, 2] = colors[:, 2] * 0.01

plt.figure(figsize=(18, 12))
plt.barh(x_array, y_array,
        height=0.5, color=colors, label='Alone')
# plt.xticks([r + bar_width for r in range(len(x_array))], x_labels)
plt.yticks(np.arange(size), x_labels, rotation=0, size=9)
plt.title("Labels histogram (top {})".format(size))

for i, count in enumerate(y_array):
    plt.text(y=i*0.995, x=count*1.01, s=count, size=9)
plt.show()

# %%
label_counts.tail(100)
# Out:
# milarepa                                    1
# sortavala                                   1
# earthquakes                                 1
# tatiana chizhova                            1
# saint carmel                                1
# pedro de arbues                             1
# “the life of gargantua                      1
# oprah                                       1
# the duke of medinaceli                      1
# rachel slonimskaya                          1
# vesta                                       1
# herodotus                                   1
# kerzhenets                                  1
# phigalia                                    1
# st. ildefonsus                              1
# mariana in the south                        1
# l.i. shetalova                              1
# alexios iv angelos                          1
# san pietro vincioli                         1
# strike                                      1
# amon                                        1
# pochayiv                                    1
# kikimora                                    1
# vladimir dal                                1
# marmot                                      1
# the eight names of picasso                  1
# ellora caves                                1
# k.s. petrov vodkin                          1
# alatas                                      1
# marquesa de santa cruz                      1
# defense of madrid                           1
# pyrrhus                                     1
# duke of alcudia                             1
# edmond rostand                              1
# pryazhka river                              1
# nina de callias                             1
# khan batygi                                 1
# nagchu                                      1
# seascape                                    1
# bezaleel                                    1
# marquesa de la solana                       1
# emmanual chabrier                           1
# oscar miestchaninoff                        1
# otters                                      1
# mars field                                  1
# st. vincent de paul                         1
# adelaide pastoret                           1
# st. philip benizi                           1
# georgi vereisky                             1
# a.d. romanova                               1
# oak grove of peter the great                1
# furnacheva                                  1
# temples and citadels                        1
# boer wars                                   1
# rochefort                                   1
# a.k. kashparova                             1
# jose antonio                                1
# yaks                                        1
# st. eloi                                    1
# aleksey verstovsky                          1
# eliez                                       1
# two crow                                    1
# maria teresa of ballabriga                  1
# refugees                                    1
# muley abd ar rhaman                         1
# the cadiz expedition                        1
# queen marie antoinette                      1
# st. isabella                                1
# trajan                                      1
# berlioz                                     1
# saint jacques tower                         1
# e.e. lansere                                1
# hadassh hebrew university medical center    1
# baron schwiter                              1
# grivoux                                     1
# p. sudkovskaya                              1
# pietro aretino                              1
# fabiano                                     1
# tityus                                      1
# vsevolod maksymovych                        1
# christoph von scheurl                       1
# perfumes                                    1
# misanthrope                                 1
# charles vii                                 1
# madonie                                     1
# tabernacles                                 1
# casimir margrave of brandenburg             1
# papal ceremony                              1
# i.a. ryazanovsky                            1
# emmanuel joseph sieyes                      1
# maria teresa de vallabriga                  1
# andrea palladio                             1
# allegheny city                              1
# shmelevka                                   1
# sudislavl                                   1
# december 12                                 1
# the medici cycle                            1
# old windsor                                 1
# delphic sibyl                               1
# gabriel alonso de herrera                   1
# dtype: int64
